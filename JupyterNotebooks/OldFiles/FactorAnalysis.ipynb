# %% [markdown]
# The source for this document can be found [here](https://www.datacamp.com/community/tutorials/introduction-factor-analysis) along with documentation.

# %% [markdown]
# # Factor Analysis

# %%
# %matplotlib widget
import pandas as pd
import numpy as np
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import common
from Data import Merge

# %%
data = Merge().data

# remove unused columns
data = data.drop(['RID','LDELTOTAL', 'DIGITSCOR', 'VISCODE'], axis=1) 

dataLabels = data.columns.values
dataNumpy = data.to_numpy()
rowsRemove = []
### Remove data incomplete
for i in range(len(dataNumpy)):
    count = 0
    for j in dataNumpy[i]:
        if j != '':
            count += 1
    #if count < len(dataLabels) - 2:
    if count < 32:
        rowsRemove.append(i)

data = data.drop(rowsRemove)
# Out:
# Ready!

# %%
fa = FactorAnalyzer(rotation="varimax").fit(data)

# %%
loadings = fa.loadings_
eigenvector, eigenvalues = fa.get_eigenvalues()

# %% [markdown]
# ## Scree Plot

# %%
plt.close()

xvals = range(1, data.shape[1]+1)
plt.scatter(xvals, eigenvector)
plt.plot(xvals, eigenvector)
plt.title("Scree Plot")
plt.xlabel("Factor")
plt.ylabel("Eigenvalue")
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pd.DataFrame.from_records(loadings)
# Out:
#            0         1         2
# 0   0.280989  0.007748 -0.058670
# 1   0.140497  0.051666  0.028803
# 2  -0.185383 -0.035881 -0.023261
# 3   0.527510  0.683933  0.131899
# 4   0.778869  0.360983  0.094877
# 5   0.848731  0.358952  0.113086
# 6   0.805838  0.305843  0.118639
# 7  -0.721653 -0.395883 -0.083473
# 8  -0.764897 -0.239738 -0.117710
# 9  -0.539211 -0.236029 -0.068004
# 10  0.247536  0.032533  0.064866
# 11  0.525081  0.171353  0.084385
# 12  0.547408  0.311426  0.114561
# 13  0.453172  0.750712  0.092094
# 14 -0.752339 -0.333010 -0.114084
# 15  0.156280  0.190594  0.778863
# 16  0.097350  0.071427  0.839087
# 17  0.145243  0.145284  0.776031
# 18  0.135318  0.162625  0.806739
# 19  0.074258  0.149770  0.761626
# 20 -0.009550  0.097249  0.802286
# 21  0.121356  0.148984  1.003740
# 22  0.374122  0.791034  0.196302
# 23  0.300946  0.777450  0.208008
# 24  0.315040  0.820483  0.131666
# 25  0.262941  0.872936  0.122940
# 26  0.271344  0.852451  0.144322
# ...

# %%
print(len(Merge().data))
# Out:
# Ready!
# 15087

# %%
len(data)
# Out:
# 5393

# %%
data
# Out:
#         AGE  PTGENDER PTEDUCAT CDRSB ADAS11 ADAS13 ADASQ4 MMSE  \
# 76     67.5         1       16     0      3      5      1   30
# 77     68.5         1       20     0      4      7      3   30
# 111    80.2         1       19     0      3      6      2   30
# 126    70.9         0       13     0      7      9      2   27
# 127    80.2         1       19     0      3     10      5   29
# ...     ...       ...      ...   ...    ...    ...    ...  ...
# 15064  75.9         0       16     0   7.67   8.67      1   30
# 15065  66.8         1       18     0  11.33  14.33      2   29
# 15067  81.3         1       12   1.5     16     24      6   24
# 15077    61         0       12     0  10.33  13.33      3   28
# 15078  71.7         0       16   0.5      9     16      4   30
#
#       RAVLT_immediate RAVLT_learning  ... EcogSPMem EcogSPLang EcogSPVisspat  \
# 76                 42              7  ...     1.625    1.11111       1.28571
# ...
